# %%
import numpy as np
import pandas as pd

from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['A','B','C','D'])

a=np.random.randn(1000, 4)
print(a)

scatter_matrix(df, alpha=0.2)
# Out:
# [[ 1.91148851 -0.86453925 -1.38516605 -1.56305072]
#  [-0.31243842 -1.09799457  0.95818599 -0.41749586]
#  [ 0.75284625  0.73770483  0.39912763  0.8725316 ]
#  ...
#  [-1.24421462  0.54757343  0.02800373  0.24930799]
#  [ 0.1627902   0.21847604  1.53776508 -0.21377278]
#  [ 0.11041845  0.3679018   0.67954041  1.62792093]]
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002169E44F748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E46EE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E499E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E4CC0C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002169E501A88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E53A488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E56FE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E5A9AC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002169E5B56C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E5ED888>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E653E08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E68EE88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002169E6C7F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E703108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E73C208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002169E774308>]],
#       dtype=object)
